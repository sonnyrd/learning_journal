# %% [markdown]
# # Week 1 : Day 4 PM // Pandas Basic 2

# %% [markdown]
# ## NBA dataset analysis

# %%
import numpy as np
import pandas as pd

# %%
#ngeload data set

#skema 1 = local-path
# pd.read_csv('filename')
# pd.read_csv('path/filename')
# pd.read_csb('../filename')
# pd.read_csv('../../filename')

#skema 2 = separator berbeda (tanda pemisah)
#contoh data1;data2;data3
#pd.read_csv('resource/ref.csv', delimiter= ';' )

#skema 3 = link/web

## untuk file selain excel read nya menggunakan read_csv

# %% [markdown]
# #### skema 1

# %%
pd.read_csv('resource/Student_Marks.csv')
# Out:
#     number_courses  time_study   Marks
# 0                3       4.508  19.202
# 1                4       0.096   7.734
# 2                4       3.133  13.811
# 3                6       7.909  53.018
# 4                8       7.811  55.299
# ..             ...         ...     ...
# 95               6       3.561  19.128
# 96               3       0.301   5.609
# 97               4       7.163  41.444
# 98               7       0.309  12.027
# 99               3       6.335  32.357
#
# [100 rows x 3 columns]

# %% [markdown]
# #### skema 2

# %%
pd.read_csv('resource/ref.csv', delimiter= ';' )
# Out:
#    ch1  ch2  ch3
# 0   10    1  100
# 1   20    2  200
# 2   30    3  300
# 3   40    4  400
# 4   50    5  500

# %% [markdown]
# #### Skema 3

# %%
df = pd.read_csv('https://raw.githubusercontent.com/ardhiraka/PFDS_sources/master/nbaallelo.csv')

# %% [markdown]
# ##### to show how much data nba contains:

# %%
# Out:
# RangeIndex(start=0, stop=126314, step=1)

# %%
#berisi berapa banyak baris
len(df)
# Out:
# 126314

# %%
#jumlah baris dan kolom
#1236314 baris dan 23 kolom

df.shape
# Out:
# (126314, 23)

# %%
df.shape[0]
# Out:
# 126314

# %%
df.shape[1]
# Out:
# 23

# %%
#df.head()
#preview 5 data teratas secara default
#df.head(2)
#preview 2 data teratas

df.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  ...  win_equiv  opp_id  opp_fran  opp_pts  \
# 0            0     TRH  Huskies  ...  40.294830     NYK    Knicks       68
# 1            0     NYK   Knicks  ...  41.705170     TRH   Huskies       66
# 2            0     CHS    Stags  ...  42.012257     NYK    Knicks       47
# 3            0     NYK   Knicks  ...  40.692783     CHS     Stags       63
# 4            0     DTF  Falcons  ...  38.864048     WSC  Capitols       50
#
#    opp_elo_i  opp_elo_n  game_location  game_result  forecast notes
# ...

# %%
#set display colums agar semua terdisplay
pd.set_option('display.max_columns', None)

# %%
df.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts      elo_i      elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.0000  1293.2767  40.294830    NYK
# 1            0     NYK   Knicks   68  1300.0000  1306.7233  41.705170    TRH
# 2            0     CHS    Stags   63  1300.0000  1309.6521  42.012257    NYK
# 3            0     NYK   Knicks   47  1306.7233  1297.0712  40.692783    CHS
# 4            0     DTF  Falcons   33  1300.0000  1279.6189  38.864048    WSC
#
# ...

# %%
#preview 5 data terbawah
#df.tail()

df.tail()
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts      elo_i      elo_n  \
# 126309         100            1     CLE  Cavaliers   82  1723.4149  1704.3949
# 126310         102            1     GSW   Warriors  104  1809.9791  1813.6349
# 126311         101            1     CLE  Cavaliers   91  1704.3949  1700.7391
# 126312         102            1     CLE  Cavaliers   97  1700.7391  1692.0859
# 126313         103            1     GSW   Warriors  105  1813.6349  1822.2881
#
#         win_equiv opp_id   opp_fran  opp_pts  opp_elo_i  opp_elo_n  \
# ...

# %% [markdown]
# ## Getting to Know Your Data

# %% [markdown]
# ### Data overview

# %%
df.info()

#Non-Null Count = missing values
#Dtype = type data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  object
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  elo_i          126314 non-null  float64
#  12  elo_n          126314 non-null  float64
#  13  win_equiv      126314 non-null  float64
#  14  opp_id         126314 non-null  object
#  15  opp_fran       126314 non-null  object
#  16  opp_pts        126314 non-null  int64
# ...

# %% [markdown]
# ### Show basic statistic

# %%
#df.describe()
#df.describe(),T < transpose
df.describe().T
# Out:
#                 count          mean           std          min           25%  \
# gameorder    126314.0  31579.000000  18231.927643     1.000000  15790.000000
# _iscopy      126314.0      0.500000      0.500002     0.000000      0.000000
# year_id      126314.0   1988.200374     17.582309  1947.000000   1975.000000
# seasongame   126314.0     43.533733     25.375178     1.000000     22.000000
# is_playoffs  126314.0      0.063857      0.244499     0.000000      0.000000
# pts          126314.0    102.729982     14.814845     0.000000     93.000000
# elo_i        126314.0   1495.236055    112.139945  1091.644500   1417.237975
# elo_n        126314.0   1495.236055    112.461687  1085.774400   1416.994900
# win_equiv    126314.0     41.707889     10.627332    10.152501     34.103035
# opp_pts      126314.0    102.729982     14.814845     0.000000     93.000000
# opp_elo_i    126314.0   1495.236055    112.139945  1091.644500   1417.237975
# ...

# %% [markdown]
# ### Data Exploration

# %%
df.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts      elo_i      elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.0000  1293.2767  40.294830    NYK
# 1            0     NYK   Knicks   68  1300.0000  1306.7233  41.705170    TRH
# 2            0     CHS    Stags   63  1300.0000  1309.6521  42.012257    NYK
# 3            0     NYK   Knicks   47  1306.7233  1297.0712  40.692783    CHS
# 4            0     DTF  Falcons   33  1300.0000  1279.6189  38.864048    WSC
#
# ...

# %%
df['game_result'].unique()
# Out:
# array(['L', 'W'], dtype=object)

# %%
df['game_result'].value_counts()
# Out:
# L    63157
# W    63157
# Name: game_result, dtype: int64

# %%
df['fran_id'].value_counts()
# Out:
# Lakers          6024
# Celtics         5997
# Knicks          5769
# Warriors        5657
# Pistons         5650
# Sixers          5644
# Hawks           5572
# Kings           5475
# Wizards         4582
# Spurs           4309
# Bulls           4307
# Pacers          4227
# Thunder         4178
# Rockets         4154
# Nuggets         4120
# Nets            4106
# Suns            4080
# Bucks           4034
# Trailblazers    3870
# Cavaliers       3810
# Clippers        3733
# Jazz            3555
# Mavericks       3013
# Heat            2371
# Pelicans        2254
# Magic           2207
# Timberwolves    2131
# Grizzlies       1657
# Raptors         1634
# Hornets          894
# Colonels         846
# Squires          799
# Spirits          777
# Stars            756
# Sounds           697
# Baltimore        467
# Floridians       440
# Condors          430
# Capitols         291
# Olympians        282
# Sails            274
# Stags            260
# Bombers          249
# ...

# %%
df.sort_values(by='pts',ascending=True)[['year_id','fran_id','pts',]]
# Out:
#        year_id  fran_id  pts
# 26684     1973  Nuggets    0
# 26685     1973  Squires    2
# 3190      1951   Lakers   18
# 3191      1951  Pistons   19
# 4         1947  Falcons   33
# ...        ...      ...  ...
# 8974      1959  Celtics  173
# 32881     1975    Sails  176
# 21416     1970   Pacers  177
# 50095     1984  Nuggets  184
# 50094     1984  Pistons  186
#
# [126314 rows x 3 columns]

# %%
df.loc[df["fran_id"] == "Knicks",:]
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 1               1  194611010TRH   NBA        1     1947   11/1/1946
# 3               2  194611020CHS   NBA        1     1947   11/2/1946
# 23             12  194611070STB   NBA        1     1947   11/7/1946
# 37             19  194611110NYK   NBA        0     1947  11/11/1946
# 54             28  194611160NYK   NBA        0     1947  11/16/1946
# ...           ...           ...   ...      ...      ...         ...
# 126025      63013  201504080NYK   NBA        0     2015    4/8/2015
# 126056      63029  201504100NYK   NBA        0     2015   4/10/2015
# 126072      63037  201504110ORL   NBA        1     2015   4/11/2015
# 126094      63048  201504130ATL   NBA        1     2015   4/13/2015
# 126147      63074  201504150NYK   NBA        0     2015   4/15/2015
#
#         seasongame  is_playoffs team_id fran_id  pts      elo_i      elo_n  \
# ...

# %%
df.loc[df["fran_id"] == "Knicks","opp_fran"].value_counts()
# Out:
# Celtics         526
# Sixers          471
# Pistons         382
# Hawks           368
# Warriors        335
# Wizards         323
# Lakers          310
# Kings           299
# Bulls           251
# Pacers          205
# Bucks           204
# Cavaliers       203
# Nets            189
# Rockets         145
# Heat            137
# Thunder         124
# Clippers        122
# Suns            120
# Trailblazers    105
# Magic            99
# Pelicans         90
# Jazz             90
# Spurs            90
# Raptors          85
# Nuggets          81
# Mavericks        68
# Baltimore        62
# Timberwolves     50
# Hornets          40
# Grizzlies        37
# Capitols         32
# Stags            23
# Bombers          23
# Olympians        20
# Steamrollers     20
# Rebels            9
# Falcons           6
# Ironmen           6
# Huskies           6
# Jets              5
# Packers           2
# Denver            2
# Redskins          2
# Waterloo          2
# Name: opp_fran, dtype: int64

# %%
df.loc[df["year_id"] == 2010,:]
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 111032      55517  200910270CLE   NBA        1     2010  10/27/2009
# 111033      55517  200910270CLE   NBA        0     2010  10/27/2009
# 111034      55518  200910270DAL   NBA        1     2010  10/27/2009
# 111035      55518  200910270DAL   NBA        0     2010  10/27/2009
# 111036      55519  200910270LAL   NBA        1     2010  10/27/2009
# ...           ...           ...   ...      ...      ...         ...
# 113651      56826  201006130BOS   NBA        0     2010   6/13/2010
# 113652      56827  201006150LAL   NBA        1     2010   6/15/2010
# 113653      56827  201006150LAL   NBA        0     2010   6/15/2010
# 113654      56828  201006170LAL   NBA        0     2010   6/17/2010
# 113655      56828  201006170LAL   NBA        1     2010   6/17/2010
#
#         seasongame  is_playoffs team_id    fran_id  pts      elo_i      elo_n  \
# ...

# %%
df.head(2)
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
#
#    is_playoffs team_id  fran_id  pts   elo_i      elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.0  1293.2767   40.29483    NYK
# 1            0     NYK   Knicks   68  1300.0  1306.7233   41.70517    TRH
#
#   opp_fran  opp_pts  opp_elo_i  opp_elo_n game_location game_result  forecast  \
# 0   Knicks       68     1300.0  1306.7233             H           L  0.640065
# 1  Huskies       66     1300.0  1293.2767             A           W  0.359935
#
#   notes
# 0   NaN
# 1   NaN

# %%
df.loc[(df['year_id'] == 1980)&(df['fran_id'] == 'Knicks'),:]
# Out:
#        gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 41742      20872  197910120ATL   NBA        1     1980  10/12/1979
# 41769      20885  197910130NYK   NBA        0     1980  10/13/1979
# 41792      20897  197910160NYK   NBA        0     1980  10/16/1979
# 41816      20909  197910180DET   NBA        1     1980  10/18/1979
# 41830      20916  197910190NJN   NBA        1     1980  10/19/1979
# ...          ...           ...   ...      ...      ...         ...
# 43444      21723  198003220NYK   NBA        0     1980   3/22/1980
# 43457      21729  198003230PHI   NBA        1     1980   3/23/1980
# 43468      21735  198003250CLE   NBA        1     1980   3/25/1980
# 43481      21741  198003260BOS   NBA        1     1980   3/26/1980
# 43500      21751  198003270NYK   NBA        0     1980   3/27/1980
#
#        seasongame  is_playoffs team_id fran_id  pts      elo_i      elo_n  \
# 41742           1            0     NYK  Knicks  104  1417.7286  1412.8352
# ...

# %% [markdown]
# ### Kombinasi .loc dan fungsi agregasi

# %%
df.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts      elo_i      elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.0000  1293.2767  40.294830    NYK
# 1            0     NYK   Knicks   68  1300.0000  1306.7233  41.705170    TRH
# 2            0     CHS    Stags   63  1300.0000  1309.6521  42.012257    NYK
# 3            0     NYK   Knicks   47  1306.7233  1297.0712  40.692783    CHS
# 4            0     DTF  Falcons   33  1300.0000  1279.6189  38.864048    WSC
#
# ...

# %%
# Out:
# 1947

# %% [markdown]
# team dengan fran_id huskies bermain maksinal hingga season 1947 saja, atau hanya bermain 1 season di data record

# %%
df.loc[df["team_id"] == "NYK","year_id"].max()
# Out:
# 2015

# %%
df.loc[df["team_id"] == "NYK","year_id"].agg(["min","max"])
# Out:
# min    1947
# max    2015
# Name: year_id, dtype: int64

# %% [markdown]
# team dengan fran_id Knick bermain selama season 1947 hingga 2015

# %%
# df.sample()
# nge return data random
df.sample(5)
# Out:
#        gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 27664      13833  197301090UTS   ABA        0     1973    1/9/1973
# 38798      19400  197801140BUF   NBA        1     1978   1/14/1978
# 62124      31063  198911170UTA   NBA        0     1990  11/17/1989
# 6635        3318  195511130FTW   NBA        0     1956  11/13/1955
# 51684      25843  198410300UTA   NBA        0     1985  10/30/1984
#
#        seasongame  is_playoffs team_id  fran_id  pts      elo_i      elo_n  \
# 27664          45            0     UTS    Stars  115  1601.4862  1602.7350
# 38798          40            0     WSB  Wizards   93  1588.2084  1554.6177
# 62124           7            0     UTA     Jazz  114  1542.3317  1550.2230
# 6635            4            0     FTW  Pistons   93  1527.9282  1539.5039
# 51684           3            0     UTA     Jazz  117  1471.5483  1479.1093
#
#        win_equiv opp_id  opp_fran  opp_pts  opp_elo_i  opp_elo_n  \
# ...

# %%
df.loc[df['fran_id'] == 'Warriors', 'pts'].sum()
# Out:
# 591224

# %%
df.loc[df['fran_id'] == 'Warriors', ['seasongame','pts']].sum()
# Out:
# seasongame    237531
# pts           591224
# dtype: int64

# %% [markdown]
# ### Menggunakan .iloc

# %%
df.sample(2)
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 18237        9119  196901180INA   ABA        1     1969   1/18/1969
# 124009      62005  201411190BRK   NBA        0     2015  11/19/2014
#
#         seasongame  is_playoffs team_id fran_id  pts     elo_i      elo_n  \
# 18237           41            0     LAS   Stars  129  1301.429  1308.4583
# 124009          11            0     BRK    Nets  118  1501.950  1489.5875
#
#         win_equiv opp_id opp_fran  opp_pts  opp_elo_i  opp_elo_n  \
# 18237   36.529182    INA   Pacers      128  1384.8793  1377.8500
# 124009  39.432415    MIL    Bucks      122  1367.5092  1379.8716
#
#        game_location game_result  forecast notes
# 18237              A           W  0.258070   NaN
# 124009             H           L  0.794056   NaN

# %%
df.iloc[18237:19000,:]
# Out:
#        gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 18237       9119  196901180INA   ABA        1     1969  1/18/1969          41
# 18238       9120  196901180KEN   ABA        1     1969  1/18/1969          40
# 18239       9120  196901180KEN   ABA        0     1969  1/18/1969          41
# 18240       9121  196901180MNP   ABA        0     1969  1/18/1969          41
# 18241       9121  196901180MNP   ABA        1     1969  1/18/1969          38
# ...          ...           ...   ...      ...      ...        ...         ...
# 18995       9498  196903160NYA   ABA        0     1969  3/16/1969          70
# 18996       9499  196903170PHO   NBA        0     1969  3/17/1969          79
# 18997       9499  196903170PHO   NBA        1     1969  3/17/1969          80
# 18998       9500  196903170LAS   ABA        1     1969  3/17/1969          70
# 18999       9500  196903170LAS   ABA        0     1969  3/17/1969          69
#
# ...

# %%
df.loc[18237:19000,['game_id','year_id']]
# Out:
#             game_id  year_id
# 18237  196901180INA     1969
# 18238  196901180KEN     1969
# 18239  196901180KEN     1969
# 18240  196901180MNP     1969
# 18241  196901180MNP     1969
# ...             ...      ...
# 18996  196903170PHO     1969
# 18997  196903170PHO     1969
# 18998  196903170LAS     1969
# 18999  196903170LAS     1969
# 19000  196903180BAL     1969
#
# [764 rows x 2 columns]

# %% [markdown]
# ## Query dataset

# %%
df.sample(5)
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 67508       33755  199201090CHH   NBA        0     1992    1/9/1992
# 102925      51463  200604170MIL   NBA        1     2006   4/17/2006
# 62054       31028  198911120MIN   NBA        0     1990  11/12/1989
# 105536      52769  200704140UTA   NBA        1     2007   4/14/2007
# 71642       35822  199311260DEN   NBA        1     1994  11/26/1993
#
#         seasongame  is_playoffs team_id       fran_id  pts      elo_i  \
# 67508           34            0     CHH      Pelicans  109  1359.0313
# 102925          81            0     DET       Pistons   93  1704.1940
# 62054            5            0     MIN  Timberwolves   97  1301.8452
# 105536          80            0     PHO          Suns  126  1672.3174
# 71642           11            0     POR  Trailblazers  101  1555.6187
#
#             elo_n  win_equiv opp_id opp_fran  opp_pts  opp_elo_i  opp_elo_n  \
# ...

# %%
#single
df[
    df['year_id']==2001
]
# Out:
#        gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 87750      43876  200010310ATL   NBA        0     2001  10/31/2000
# 87751      43876  200010310ATL   NBA        1     2001  10/31/2000
# 87752      43877  200010310CHI   NBA        0     2001  10/31/2000
# 87753      43877  200010310CHI   NBA        1     2001  10/31/2000
# 87754      43878  200010310DAL   NBA        0     2001  10/31/2000
# ...          ...           ...   ...      ...      ...         ...
# 90265      45133  200106100PHI   NBA        0     2001   6/10/2001
# 90266      45134  200106130PHI   NBA        0     2001   6/13/2001
# 90267      45134  200106130PHI   NBA        1     2001   6/13/2001
# 90268      45135  200106150PHI   NBA        0     2001   6/15/2001
# 90269      45135  200106150PHI   NBA        1     2001   6/15/2001
#
#        seasongame  is_playoffs team_id    fran_id  pts      elo_i      elo_n  \
# 87750           1            0     ATL      Hawks   82  1366.9685  1354.0496
# ...

# %%
#Multiple

df[
    (df['year_id']==2001) &
    (df['fran_id']== 'Celtics') &
    (df['game_location']=='H') &
    (df['game_result']== 'W')
] [['fran_id','pts','opp_fran','opp_pts']]

# %%
df.query("year_id == 2001 & fran_id == 'Celtics' & game_location == 'H' & game_result == 'W' ")
# Out:
#        gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 87776      43889  200011010BOS   NBA        0     2001   11/1/2000
# 87805      43903  200011030BOS   NBA        0     2001   11/3/2000
# 87970      43986  200011150BOS   NBA        0     2001  11/15/2000
# 88001      44001  200011170BOS   NBA        0     2001  11/17/2000
# 88068      44035  200011220BOS   NBA        0     2001  11/22/2000
# 88093      44047  200011240BOS   NBA        0     2001  11/24/2000
# 88233      44117  200012030BOS   NBA        0     2001   12/3/2000
# 88336      44169  200012100BOS   NBA        0     2001  12/10/2000
# 88469      44235  200012200BOS   NBA        0     2001  12/20/2000
# 88748      44375  200101100BOS   NBA        0     2001   1/10/2001
# 88925      44463  200101230BOS   NBA        0     2001   1/23/2001
# 88975      44488  200101260BOS   NBA        0     2001   1/26/2001
# 89013      44507  200101290BOS   NBA        0     2001   1/29/2001
# ...

# %%
df.query(
    "year_id == 2001 &\
    fran_id == 'Celtics' &\
    game_location == 'H' &\
    game_result == 'W' ")
# Out:
#        gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 87776      43889  200011010BOS   NBA        0     2001   11/1/2000
# 87805      43903  200011030BOS   NBA        0     2001   11/3/2000
# 87970      43986  200011150BOS   NBA        0     2001  11/15/2000
# 88001      44001  200011170BOS   NBA        0     2001  11/17/2000
# 88068      44035  200011220BOS   NBA        0     2001  11/22/2000
# 88093      44047  200011240BOS   NBA        0     2001  11/24/2000
# 88233      44117  200012030BOS   NBA        0     2001   12/3/2000
# 88336      44169  200012100BOS   NBA        0     2001  12/10/2000
# 88469      44235  200012200BOS   NBA        0     2001  12/20/2000
# 88748      44375  200101100BOS   NBA        0     2001   1/10/2001
# 88925      44463  200101230BOS   NBA        0     2001   1/23/2001
# 88975      44488  200101260BOS   NBA        0     2001   1/26/2001
# 89013      44507  200101290BOS   NBA        0     2001   1/29/2001
# ...

# %%
df.query(
    "year_id == 2001 &\
    fran_id == 'Celtics' &\
    game_location == 'H' &\
    result == 'W' ")\
    [['fran_id','pts','opp_fran','opp_pts']]
# Out:
#        fran_id  pts   opp_fran  opp_pts
# 87776  Celtics  103    Pistons       83
# 87805  Celtics   93    Raptors       91
# 87970  Celtics  116    Wizards      109
# 88001  Celtics  106      Hawks       99
# 88068  Celtics   96    Rockets       81
# 88093  Celtics  103      Magic       98
# 88233  Celtics   96   Clippers       87
# 88336  Celtics  104    Nuggets      102
# 88469  Celtics   99       Nets       86
# 88748  Celtics   88       Heat       76
# 88925  Celtics   83      Hawks       82
# 88975  Celtics   99       Suns       83
# 89013  Celtics   99    Pistons       87
# 89105  Celtics  103  Cavaliers       82
# 89141  Celtics   94      Bucks       91
# 89364  Celtics   85    Thunder       82
# 89425  Celtics  103       Jazz       99
# 89525  Celtics  104    Wizards       72
# 89756  Celtics  102      Bulls       98
# 90057  Celtics   95       Nets       88

# %% [markdown]
# ### Grouping and Aggregating

# %%
df.sample(5)
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 32282       16142  197501020SAA   ABA        0     1975   1/2/1975
# 106692      53347  200801020MIA   NBA        0     2008   1/2/2008
# 88825       44413  200101150GSW   NBA        1     2001  1/15/2001
# 11711        5856  196302080LAL   NBA        1     1963   2/8/1963
# 89789       44895  200103270LAC   NBA        1     2001  3/27/2001
#
#         seasongame  is_playoffs team_id    fran_id  pts      elo_i      elo_n  \
# 32282           40            0     SAA      Spurs  122  1549.1060  1554.3804
# 106692          31            0     MIA       Heat   98  1395.2227  1384.7980
# 88825           36            0     CLE  Cavaliers  107  1441.4468  1449.9563
# 11711           61            0     CHZ    Wizards   91  1341.2123  1340.4452
# 89789           71            0     DET    Pistons   94  1397.0587  1392.2009
#
#         win_equiv opp_id  opp_fran  opp_pts  opp_elo_i  opp_elo_n  \
# ...

# %%
#mengelompokan data

gr = df.groupby('game_result')
gr

# %%
#simulasi saja untuk menampilkan

gr.get_group('L')
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# 6               4  194611020PRO   NBA        1     1947  11/2/1946
# 8               5  194611020STB   NBA        1     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126305      63153  201506070GSW   NBA        0     2015   6/7/2015
# 126306      63154  201506090CLE   NBA        1     2015   6/9/2015
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts      elo_i      elo_n  \
# 0                1            0     TRH    Huskies   66  1300.0000  1293.2767
# ...

# %%
#aggregating
df.groupby('game_result')['pts'].mean()

#round(df.groupby('game_result')['pts'].mean(),2)
#jika ingin dituliskan dengan desimal tidak lebih dari
# Out:
# game_result
# L     97.349209
# W    108.110756
# Name: pts, dtype: float64

# %% [markdown]
# rata-rata pts untuk group team yang kalah(L) adalah 97.34, sedangkan untuk rata-rata pts group yang menang adalah 108.11

# %%
#kombinasi group by dan query
# df.groupby('A').agg({'B': ['min', 'max'], 'C': 'sum'})

df[
    (df['year_id']>2010)&
    (df['fran_id']=='Spurs')
].groupby(['year_id','result']).agg({'game_id':'count'})
# Out:
#                 game_id
# year_id result
# 2011    L            25
#         W            63
# 2012    L            20
#         W            60
# 2013    L            30
#         W            73
# 2014    L            27
#         W            78
# 2015    L            31
#         W            58

# %% [markdown]
# ## Manipulating Colums
# - create new columns base on existing data
# - rename colums
# - drop colums

# %%
df.sample(5)
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 26334       13168  197203280FLO   ABA        1     1972   3/28/1972
# 81945       40973  199712300DET   NBA        1     1998  12/30/1997
# 82642       41322  199802200NJN   NBA        1     1998   2/20/1998
# 51540       25771  198404260POR   NBA        0     1984   4/26/1984
# 103027      51514  200604300CHI   NBA        0     2006   4/30/2006
#
#         seasongame  is_playoffs team_id       fran_id  pts      elo_i  \
# 26334           83            0     MMP        Sounds  107  1279.9531
# 81945           29            0     TOR       Raptors   95  1339.3318
# 82642           53            0     CLE     Cavaliers  109  1512.4641
# 51540           87            1     POR  Trailblazers  105  1523.6027
# 103027          86            1     CHI         Bulls   93  1549.9109
#
#             elo_n  win_equiv opp_id    opp_fran  opp_pts  opp_elo_i  \
# ...

# %%
# create new columns based on existing data

df['selisih poin'] = abs(df['pts'] - df['opp_pts'])

# %%
df.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts      elo_i      elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.0000  1293.2767  40.294830    NYK
# 1            0     NYK   Knicks   68  1300.0000  1306.7233  41.705170    TRH
# 2            0     CHS    Stags   63  1300.0000  1309.6521  42.012257    NYK
# 3            0     NYK   Knicks   47  1306.7233  1297.0712  40.692783    CHS
# 4            0     DTF  Falcons   33  1300.0000  1279.6189  38.864048    WSC
#
# ...

# %%
#rename colums
df.rename(columns={"game_result": "result"},inplace=True)

#rename tidak mensave hasil perubahan, untuk men save perubahan maka
#df.rename(columns={"game_result": "result"},inplace=True)

# %%
df.head(5)
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts      elo_i      elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.0000  1293.2767  40.294830    NYK
# 1            0     NYK   Knicks   68  1300.0000  1306.7233  41.705170    TRH
# 2            0     CHS    Stags   63  1300.0000  1309.6521  42.012257    NYK
# 3            0     NYK   Knicks   47  1306.7233  1297.0712  40.692783    CHS
# 4            0     DTF  Falcons   33  1300.0000  1279.6189  38.864048    WSC
#
# ...

# %%
# drop columns
df.drop(['elo_i', 'elo_n'], axis =1, inplace=True)

# %%
df
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts  win_equiv opp_id  \
# 0                1            0     TRH    Huskies   66  40.294830    NYK
# ...
